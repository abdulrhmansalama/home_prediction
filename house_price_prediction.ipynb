# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mpl_toolkits
# %matplotlib inline

# %%
data= pd.read_csv('/content/data.csv')

# %%
data.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
data['date'] = pd.to_datetime(data['date'])

# %%
data.shape
# Out:
# (4600, 18)

# %%
data.describe()
# Out:
#                                 date         price     bedrooms    bathrooms  \
# count                           4600  4.600000e+03  4600.000000  4600.000000
# mean   2014-06-07 03:14:42.782608640  5.519630e+05     3.400870     2.160815
# min              2014-05-02 00:00:00  0.000000e+00     0.000000     0.000000
# 25%              2014-05-21 00:00:00  3.228750e+05     3.000000     1.750000
# 50%              2014-06-09 00:00:00  4.609435e+05     3.000000     2.250000
# 75%              2014-06-24 00:00:00  6.549625e+05     4.000000     2.500000
# max              2014-07-10 00:00:00  2.659000e+07     9.000000     8.000000
# std                              NaN  5.638347e+05     0.908848     0.783781
#
#         sqft_living      sqft_lot       floors   waterfront         view  \
# count   4600.000000  4.600000e+03  4600.000000  4600.000000  4600.000000
# mean    2139.346957  1.485252e+04     1.512065     0.007174     0.240652
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   datetime64[ns]
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
data.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
data["country"].unique()
# Out:
# array(['USA'], dtype=object)

# %%
data["bedrooms"].value_counts().plot(kind="bar")
plt.title("number of bedrooms")
plt.xlabel("bedrooms")
plt.ylabel("count")
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
 s=data['price']==0
 s.value_counts()
# Out:
# price
# False    4551
# True       49
# Name: count, dtype: int64

# %%
data['price'] = data['price'].replace(0, np.nan)

# %%
data
# Out:
#            date         price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0    2014-05-02  3.130000e+05       3.0       1.50         1340      7912
# 1    2014-05-02  2.384000e+06       5.0       2.50         3650      9050
# 2    2014-05-02  3.420000e+05       3.0       2.00         1930     11947
# 3    2014-05-02  4.200000e+05       3.0       2.25         2000      8030
# 4    2014-05-02  5.500000e+05       4.0       2.50         1940     10500
# ...         ...           ...       ...        ...          ...       ...
# 4595 2014-07-09  3.081667e+05       3.0       1.75         1510      6360
# 4596 2014-07-09  5.343333e+05       3.0       2.50         1460      7573
# 4597 2014-07-09  4.169042e+05       3.0       2.50         3010      7014
# 4598 2014-07-10  2.034000e+05       4.0       2.00         2090      6630
# 4599 2014-07-10  2.206000e+05       3.0       2.50         1490      8102
#
#       floors  waterfront  view  condition  sqft_above  sqft_basement  \
# ...

# %%
data.dropna(subset=["price"], inplace=True)

# %%
data
# Out:
#            date         price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0    2014-05-02  3.130000e+05       3.0       1.50         1340      7912
# 1    2014-05-02  2.384000e+06       5.0       2.50         3650      9050
# 2    2014-05-02  3.420000e+05       3.0       2.00         1930     11947
# 3    2014-05-02  4.200000e+05       3.0       2.25         2000      8030
# 4    2014-05-02  5.500000e+05       4.0       2.50         1940     10500
# ...         ...           ...       ...        ...          ...       ...
# 4595 2014-07-09  3.081667e+05       3.0       1.75         1510      6360
# 4596 2014-07-09  5.343333e+05       3.0       2.50         1460      7573
# 4597 2014-07-09  4.169042e+05       3.0       2.50         3010      7014
# 4598 2014-07-10  2.034000e+05       4.0       2.00         2090      6630
# 4599 2014-07-10  2.206000e+05       3.0       2.50         1490      8102
#
#       floors  waterfront  view  condition  sqft_above  sqft_basement  \
# ...

# %%
plt.scatter(data['price'],data['sqft_living'])
plt.xlabel("price")
plt.ylabel("sqft_living")
plt.title("price vs sqft_living")
# Out:
# Text(0.5, 1.0, 'price vs sqft_living')

# %%
plt.scatter(data['bedrooms']+data['bathrooms'],data['price'])
plt.xlabel("price")
plt.ylabel("bedrooms , bathrooms")
plt.title("price vs bedrooms+bathrooms")
# Out:
# Text(0.5, 1.0, 'price vs bedrooms+bathrooms')

# %%
plt.scatter(data['waterfront'],data['price'])
plt.xlabel("waterfront")
plt.ylabel("price")
plt.title("waterfront vs price")
# Out:
# Text(0.5, 1.0, 'waterfront vs price')

# %%
train=data.drop(['price'],axis=1)

# %%
train.head()
# Out:
#         date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0 2014-05-02       3.0       1.50         1340      7912     1.5           0
# 1 2014-05-02       5.0       2.50         3650      9050     2.0           0
# 2 2014-05-02       3.0       2.00         1930     11947     1.0           0
# 3 2014-05-02       3.0       2.25         2000      8030     1.0           0
# 4 2014-05-02       4.0       2.50         1940     10500     1.0           0
#
#    view  condition  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3        1340              0      1955          2005
# 1     4          5        3370            280      1921             0
# 2     0          4        1930              0      1966             0
# 3     0          4        1000           1000      1963             0
# 4     0          4        1140            800      1976          1992
#
#                      street       city  statezip country
# ...

# %%
data.floors.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='floors'>

# %%
plt.scatter(data['floors'],data['price'])
plt.xlabel("floors")
plt.ylabel("price")
plt.title("floors vs price")
# Out:
# Text(0.5, 1.0, 'floors vs price')

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
# lable=data['price']
# conv_date=[1 if values ==2014 else 0 for values in data['date']]
# data['date']=conv_date
# train1=data.drop(['price'],axis=1)

# %%
# data.head()

# %%
from sklearn.model_selection import train_test_split

# %%
data['street']=data['street'].astype('category').cat.codes
data['city']=data['city'].astype('category').cat.codes
data['statezip']=data['statezip'].astype('category').cat.codes
data['date']=data['statezip'].astype('category').cat.codes
data['country']=data['country'].astype('category').cat.codes

data
# Out:
#       date         price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0       62  3.130000e+05       3.0       1.50         1340      7912     1.5
# 1       58  2.384000e+06       5.0       2.50         3650      9050     2.0
# 2       26  3.420000e+05       3.0       2.00         1930     11947     1.0
# 3        7  4.200000e+05       3.0       2.25         2000      8030     1.0
# 4       31  5.500000e+05       4.0       2.50         1940     10500     1.0
# ...    ...           ...       ...        ...          ...       ...     ...
# 4595    62  3.081667e+05       3.0       1.75         1510      6360     1.0
# 4596     6  5.343333e+05       3.0       2.50         1460      7573     2.0
# 4597    37  4.169042e+05       3.0       2.50         3010      7014     2.0
# 4598    71  2.034000e+05       4.0       2.00         2090      6630     1.0
# 4599    26  2.206000e+05       3.0       2.50         1490      8102     2.0
#
# ...

# %%
selected_features=data.drop(['date','country'],axis='columns')
selected_features
# Out:
#              price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     3.130000e+05       3.0       1.50         1340      7912     1.5
# 1     2.384000e+06       5.0       2.50         3650      9050     2.0
# 2     3.420000e+05       3.0       2.00         1930     11947     1.0
# 3     4.200000e+05       3.0       2.25         2000      8030     1.0
# 4     5.500000e+05       4.0       2.50         1940     10500     1.0
# ...            ...       ...        ...          ...       ...     ...
# 4595  3.081667e+05       3.0       1.75         1510      6360     1.0
# 4596  5.343333e+05       3.0       2.50         1460      7573     2.0
# 4597  4.169042e+05       3.0       2.50         3010      7014     2.0
# 4598  2.034000e+05       4.0       2.00         2090      6630     1.0
# 4599  2.206000e+05       3.0       2.50         1490      8102     2.0
#
#       waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
corr_matrix=selected_features.corr(method="pearson")
plt.figure(figsize=(10,10))
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
high_corr_feature=corr_matrix.index[abs(corr_matrix['price'])>=0.2].tolist()
high_corr_feature.remove('price')# Remove the target variable from the list
print(high_corr_feature)
# Out:
# ['bedrooms', 'bathrooms', 'sqft_living', 'view', 'sqft_above', 'sqft_basement']

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score

# %%
y=data['price']
x=data[high_corr_feature]
scaler = StandardScaler()
scaler.fit(x)
x=scaler.transform(x)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
X_train = scaler.fit_transform(x_train)
X_test = scaler.transform(x_test)

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_test_pre=reg.predict(x_test)
test_acc=r2_score(y_test,y_test_pre)
test_acc
# Out:
# 0.0578852148319684
